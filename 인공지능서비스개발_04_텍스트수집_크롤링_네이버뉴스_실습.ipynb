# %% [markdown]
# # 1. 네이버 뉴스 Crawling with Naver Open API

# %%
# 네이버 검색 API 예제 -  블로그 검색 예제를 뉴스 검색 예제로 수정하여 실행
import os
import sys
import urllib.request
client_id = "mhCagi9AsUisdxi8BhF9"
client_secret = "g48dDAgDGJ"
encText = urllib.parse.quote("wti")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:51:59 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }

# %%
# 네이버 검색 API 예제 기반으로 네이버 검색 API 동작 방식 확인 (검색 결과 모두 받기)
# rescode가 200인 동안 start를 증가시켜서 계속 검색 (테스트를 위해 start는 25이하로 제한)

import os
import sys
import urllib.request
client_id = "mhCagi9AsUisdxi8BhF9"
client_secret = "g48dDAgDGJ"
encText = urllib.parse.quote("wti")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과

start = 1
display = 10
rescode = 200
while True:
    try:
        new_url = url + f'&start{start}&display={display}'
        request = urllib.request.Request(new_url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        if(rescode==200):
            response_body = response.read()
            print(response_body.decode('utf-8'))
        else:
            print("Error Code:" + rescode)
        start += display
    except Exception as e:
        print(e)
        print(f'Error : {new_url}')
        break
# Out:
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:51:59 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:51:59 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:51:59 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:51:59 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Tue, 14 Apr 2026 20:52:00 +0900",
# 	"total":411250,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트",
# 			"link":"https:\/\/blog.naver.com\/scho990\/224211887501",
# 			"description":"<b>wti<\/b> 선물 가격 유가 실시간 차트 시세 사이트 국제 유가가 한 번씩 출렁일 때마다 저는 괜히 불안해지더라고요. 뉴스에서 <b>WTI<\/b> 배럴당 몇 달러라는 숫자가 나오면 &quot;지금이 비싼 건지 싼 건지&quot; 감이 잘 안... ",
# 			"bloggername":"루시펠의 잡다한 블로그",
# 			"bloggerlink":"blog.naver.com\/scho990",
# 			"postdate":"20260310"
# 		},
# 		{
# 			"title":"<b>WTI<\/b>, 브렌트유, 두바이유, 국제유가 3대장 완벽 비교",
# 			"link":"https:\/\/blog.naver.com\/next200208\/224225384747",
# 			"description":"우리가 뉴스나 경제 지표에서 자주 보고 있는 &lt;<b>WTI<\/b>, 브렌트유, 두바이유&gt; 인데요. 이를 3대 지표... 품질은 <b>WTI<\/b>(미국 서부 텍사스산 원유)가 가장 좋고, 안정적 공급량은 두바이유 입니다. 따라서, 우리나라는... ",
# 			"bloggername":"꿀팁, 안선생",
# 			"bloggerlink":"blog.naver.com\/next200208",
# 			"postdate":"20260324"
# 		},
# 		{
# 			"title":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은?",
# 			"link":"https:\/\/blog.naver.com\/blogbaksa\/224204933390",
# 			"description":"실시간국제유가<b>wti<\/b> 사이트 바로가기 확인 방법 전망은? 기름값이 한 번씩 훅 오를 때마다 주유소에... 그러던 중 2025년 초 유가가 갑자기 출렁이던 시기에, 지인이 <b>WTI<\/b> 유가를 실시간으로 볼 수 있는 사이트를... ",
# 			"bloggername":"아파트,상가,빌라 분양정보",
# 			"bloggerlink":"blog.naver.com\/blogbaksa",
# 			"postdate":"20260305"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 120달러, 확률 67%: 폴리마켓 자금들이 몰리고 있음",
# 			"link":"https:\/\/blog.naver.com\/economicfreedom2030\/224239040328",
# 			"description":"즉 <b>WTI<\/b>예측 그만큼 핫한 주제라는말 유가 120달러 확률 66%의 공포 <b>WTI<\/b> 유가 베팅 현황을 보면 이건 단순한 엄포가 아님 <b>WTI<\/b> 120달러 돌파: 확률 66% (메인 승부처) <b>WTI<\/b> 130달러 이상: 확률 36% (3명 중 1명은... ",
# 			"bloggername":"하루하루의 투자와 일상",
# 			"bloggerlink":"blog.naver.com\/economicfreedom2030",
# 			"postdate":"20260403"
# 		},
# 		{
# 			"title":"국제유가를 결정짓는 <b>WTI<\/b>유 브렌트유 두바이유 차이점은?",
# 			"link":"https:\/\/blog.naver.com\/totoro3123\/224235257212",
# 			"description":"오늘은 뉴스에서 매일같이 들리는 '<b>WTI<\/b>유', '브렌트유', 그리고 우리와 아주 밀접한 '두바이유'까지, 이... 국제유가의 주인공들: <b>WTI<\/b>, 브렌트, 두바이 국제유가를 결정짓는 기준이 되는 원유를 '벤치마크(Benchmark)... ",
# 			"bloggername":"너부리의 주식경제노트",
# 			"bloggerlink":"blog.naver.com\/totoro3123",
# 			"postdate":"20260331"
# 		},
# 		{
# 			"title":"트럼프 2주 휴전 전격 합의! 4월 종료 시나리오 <b>WTI<\/b> 유가 전망",
# 			"link":"https:\/\/blog.naver.com\/jin0oo\/224245138099",
# 			"description":"4월 종료 시나리오 <b>WTI<\/b> 유가 전망 글로벌 경제를 뒤흔들고 있는 미국 이란 전쟁이 새로운 국면을... 급등했던 <b>WTI<\/b> 유가 동향 금융시장에서 이번 전쟁을 가장 두려워했던 이유는 바로 '국제 유가 폭등... ",
# 			"bloggername":"하이스타",
# 			"bloggerlink":"blog.naver.com\/jin0oo",
# 			"postdate":"20260408"
# 		},
# 		{
# 			"title":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니...",
# 			"link":"https:\/\/blog.naver.com\/ggokyu\/224242510307",
# 			"description":"&quot;브렌트유&quot; vs 두바이유 <b>WTI<\/b> 유가 차이점 알아보니... 최근 연일 '국제유가 급등'이라는 기사가... 어떤 날은 <b>WTI<\/b>가 올랐다고 하고, 어떤 날은 브렌트유나 두바이유 가격을 이야기한다. 똑같은 석유 같은데 왜... ",
# 			"bloggername":"짠테크 연구소",
# 			"bloggerlink":"blog.naver.com\/ggokyu",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>WTI<\/b> 유가 재반등, 지금이라도 투자해야할까?",
# 			"link":"https:\/\/blog.naver.com\/lancelot85\/224250918657",
# 			"description":"중동 지역의 긴장감이 다시 고조되면서 <b>WTI<\/b> 유가가 다시 치솟았다. 지난주까지만 해도 휴전 협상에 대한 기대감으로 잠잠했던 국제유가는, 협상 결렬 소식이 전해지자마자 <b>WTI<\/b>유 선물은 단 하루 만에 7% 넘게... ",
# 			"bloggername":"재클쌤의 경제7스푼",
# 			"bloggerlink":"blog.naver.com\/lancelot85",
# 			"postdate":"20260413"
# 		},
# 		{
# 			"title":"세계 3대 원유 <b>WTI<\/b> 브렌트 두바이유 알아보기",
# 			"link":"https:\/\/blog.naver.com\/librarygoer\/224238040033",
# 			"description":"그럼, 서부텍사스(<b>WTI<\/b>)유, 브렌트(Brent)유, 두바이(Dubai)유에 대해 알아보자. 세계 3대 원유가 대표하는... 그 중에서 기준이 되는 3가지 원유가 바로 <b>WTI<\/b>유, 브렌트유, 두바이유다. 왜 기준이 되었나? 원유가 가장... ",
# 			"bloggername":"공감 쩐다. T경제",
# 			"bloggerlink":"blog.naver.com\/librarygoer",
# 			"postdate":"20260402"
# 		},
# 		{
# 			"title":"국제유가 급락, <b>WTI<\/b> 하루 만에 8% 급락! 그 배경은?",
# 			"link":"https:\/\/blog.naver.com\/kingpro_\/224211331248",
# 			"description":"글로벌 원유 시장의 대표 지표인 서부텍사스산원유(<b>WTI<\/b>) 가격은 장중 고점 대비 약 8% 가까이 하락하면서 큰 변동성을 나타냈는데요. 불과 하루 전 날에는 유가가 배럴당 120달러에 근접하며 급등세를 보이기도... ",
# 			"bloggername":"왕프로의 경제와 오피스",
# 			"bloggerlink":"blog.naver.com\/kingpro_",
# 			"postdate":"20260311"
# 		}
# 	]
# }
# HTTP Error 429: Too Many Requests
# Error : https://openapi.naver.com/v1/search/blog?query=wti&start151&display=10

# %% [markdown]
# # 2. NaverNewsCrawler 개발
# 1. 네이버 뉴스 API로 Crawling : **crawlNaverNews(keyword)** -> 파이썬 json 데이터
# 1. 응답데이터를 리스트에 저장 : **mergeResultToList(result_list, merged_list)** -> List
# 1. 응답데이터가 없을 때까지 반복
# 1. 리스트를 CSV 파일로 저장 : **saveJSONListToCSV(merged_list, csv_filename)**

# %%
# 검색 API 호출, 응답을 JSON 데이터로 return하는 함수 작성
# API 호출 결과에 문제가 있을 경우 exception으로 처리
# exception 발생 시 exception과 호출 url 확인 (try : ... except Exception as e: ... )

import os
import sys
import urllib.request
import json
import time

def crawlNaverNews(keyword, start, display=10):
    client_id = "mhCagi9AsUisdxi8BhF9"
    client_secret = "g48dDAgDGJ"
    encText = urllib.parse.quote(keyword)
    url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과

    new_url = url + f'&start{start}&display={display}'
    request = urllib.request.Request(new_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        #json 문자열을 python 객체로 변환
        py_data = json.loads(json_data)
        #print(py_data['items'])
        time.sleep(0.1)
        return py_data

    else:
        print("Error Code:" + rescode)
        return None

# %%
# 응답데이터를 리스트에 통합
def mergeResultToList(result_list, merged_list):
    for result in result_list:
        merged_list.append(result)

# %%
# JSON의 list를 dataframe으로 변환하여 csv 파일로 저장

# %%
keyword = '원유'

# API 호출 결과 전송된 JSON이 없거나, 전송된 JSON에 검색 결과가 없을 때까지
# 검색 결과를 JSON의 list로 저장 후 검색 API 추가 호출

# 검색 결과를 저장할 list 초기화
resultAll = []

start = 1
while start < 1000:
    crawled_data = crawlNaverNews(keyword, start)
    if crawled_data : 
        print('crawling 성공 :', start )
        resultAll += crawled_data['items']
        start += 10
    else : 
        print('crawling 실패 :', start)
        break
# Out:
# crawling 성공 : 1
# crawling 성공 : 11
# crawling 성공 : 21
# crawling 성공 : 31
# crawling 성공 : 41
# crawling 성공 : 51
# crawling 성공 : 61
# crawling 성공 : 71
# crawling 성공 : 81
# crawling 성공 : 91
# crawling 성공 : 101
# crawling 성공 : 111
# crawling 성공 : 121
# crawling 성공 : 131
# crawling 성공 : 141
# crawling 성공 : 151
# crawling 성공 : 161
# crawling 성공 : 171
# crawling 성공 : 181
# crawling 성공 : 191
# crawling 성공 : 201
# crawling 성공 : 211
# crawling 성공 : 221
# crawling 성공 : 231
# crawling 성공 : 241
# crawling 성공 : 251
# crawling 성공 : 261
# crawling 성공 : 271
# crawling 성공 : 281
# crawling 성공 : 291
# crawling 성공 : 301
# crawling 성공 : 311
# crawling 성공 : 321
# crawling 성공 : 331
# crawling 성공 : 341
# crawling 성공 : 351
# crawling 성공 : 361
# crawling 성공 : 371
# crawling 성공 : 381
# crawling 성공 : 391
# crawling 성공 : 401
# crawling 성공 : 411
# crawling 성공 : 421
# crawling 성공 : 431
# crawling 성공 : 441
# crawling 성공 : 451
# crawling 성공 : 461
# crawling 성공 : 471
# crawling 성공 : 481
# crawling 성공 : 491
# crawling 성공 : 501
# crawling 성공 : 511
# crawling 성공 : 521
# crawling 성공 : 531
# crawling 성공 : 541
# crawling 성공 : 551
# crawling 성공 : 561
# crawling 성공 : 571
# crawling 성공 : 581
# crawling 성공 : 591
# crawling 성공 : 601
# crawling 성공 : 611
# crawling 성공 : 621
# crawling 성공 : 631
# crawling 성공 : 641
# crawling 성공 : 651
# crawling 성공 : 661
# crawling 성공 : 671
# crawling 성공 : 681
# crawling 성공 : 691
# crawling 성공 : 701
# crawling 성공 : 711
# crawling 성공 : 721
# crawling 성공 : 731
# crawling 성공 : 741
# crawling 성공 : 751
# crawling 성공 : 761
# crawling 성공 : 771
# crawling 성공 : 781
# crawling 성공 : 791
# crawling 성공 : 801
# crawling 성공 : 811
# crawling 성공 : 821
# crawling 성공 : 831
# crawling 성공 : 841
# crawling 성공 : 851
# crawling 성공 : 861
# crawling 성공 : 871
# crawling 성공 : 881
# crawling 성공 : 891
# crawling 성공 : 901
# crawling 성공 : 911
# crawling 성공 : 921
# crawling 성공 : 931
# crawling 성공 : 941
# crawling 성공 : 951
# crawling 성공 : 961
# crawling 성공 : 971
# crawling 성공 : 981
# crawling 성공 : 991

# %%
resultAll[:2]
# Out:
# [{'title': "현대·GS건설 등 차량 5부제 동참…'현장은 예외, 관리직만 압박'",
#   'originallink': 'http://www.fntimes.com/html/view.php?ud=202604142045042752048b718333_18',
#   'link': 'http://www.fntimes.com/html/view.php?ud=202604142045042752048b718333_18',
#   'description': '<b>원유</b> 수급 위기와 대기오염 대응을 위해 시행된 차량 5부제·2부제가 건설업계 전반으로 확산되고 있다. 지난 3월 26일 5부제 시행에 이어 4월 8일부터 2부제가 도입되면서 규제 수위가 높아졌고, 민간 건설사들도 자율 참여... ',
#   'pubDate': 'Tue, 14 Apr 2026 20:50:00 +0900'},
#  {'title': '국제기구들, 호르무즈 역봉쇄한 미국 향해 ‘에너지 위기’ 일제 경고',
#   'originallink': 'https://www.khan.co.kr/article/202604142049005',
#   'link': 'https://n.news.naver.com/mnews/article/032/0003439897?sid=104',
#   'description': '이란산 <b>원유</b> 수출 차단을 시도하자 국제통화기금(IMF)과 세계은행그룹(WBG), 국제에너지기구(IEA)가 전 세계에... IEA는 미·이스라엘의 공격으로 이란 내 <b>원유</b> 생산 및 정유 시설 등 80곳이 타격을 입었으며 이 중 3분의 1... ',
#   'pubDate': 'Tue, 14 Apr 2026 20:49:00 +0900'}]

# %%
import pandas as pd
data_df = pd.DataFrame(resultAll)
data_df.to_csv(f'./data/{keyword}_navernews.csv')

# %%
# 검색어 입력
keyword = 'wti'

# API 호출 결과 전송된 JSON이 없거나, 전송된 JSON에 검색 결과가 없을 때까지
# 검색 결과를 JSON의 list로 저장 후 검색 API 추가 호출


# 검색 결과를 저장할 list 초기화
resultAll = []

# 첫 검색 API 호출을 위한 데이터 초기화
start = 1
display = 10
while True:
    crawled_data = crawlNaverNews(keyword, start)
    # API 호출 성공 여부 출력
    if crawled_data:
        print(f'{keyword} [{start}] : 검색 성공')
    else:
        print(f'{keyword} [{start}] : 검색 실패')
        break
    
    # crawling된 데이터가 없으면 중지

    # 응답데이터 정리하여 리스트로 통합
    mergeResultToList(crawled_data, resultAll)
    # 다음 검색 API 호출을 위한 파라미터 조정
    start += display
    
    
   
    

# 리스트를 csv 파일로 저장
# Out:
# wti [1] : 검색 성공
# wti [11] : 검색 성공
# wti [21] : 검색 성공
# wti [31] : 검색 성공
# wti [41] : 검색 성공
# wti [51] : 검색 성공
# wti [61] : 검색 성공
# wti [71] : 검색 성공
# wti [81] : 검색 성공
# wti [91] : 검색 성공
# wti [101] : 검색 성공
# wti [111] : 검색 성공
# wti [121] : 검색 성공
# wti [131] : 검색 성공
# wti [141] : 검색 성공
# wti [151] : 검색 성공
# wti [161] : 검색 성공
# wti [171] : 검색 성공
# wti [181] : 검색 성공
# wti [191] : 검색 성공
# wti [201] : 검색 성공
# wti [211] : 검색 성공
# wti [221] : 검색 성공
# wti [231] : 검색 성공
# wti [241] : 검색 성공
# wti [251] : 검색 성공
# wti [261] : 검색 성공
# wti [271] : 검색 성공
# wti [281] : 검색 성공
# wti [291] : 검색 성공
# wti [301] : 검색 성공
# wti [311] : 검색 성공
# wti [321] : 검색 성공
# wti [331] : 검색 성공
# wti [341] : 검색 성공
# wti [351] : 검색 성공
# wti [361] : 검색 성공
# wti [371] : 검색 성공
# wti [381] : 검색 성공
# wti [391] : 검색 성공
# wti [401] : 검색 성공
# wti [411] : 검색 성공

# %%
# 저장한 파일을 dataframe으로 loading 해보기
loaded_data_df = pd.read_csv(result_filename, index_col = 0)
loaded_data_df
